# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
DATA_DIR = Path(".")  # Current directory

# List all CSV files to verify
csv_files = list(DATA_DIR.glob("*.csv"))
print(f"Found {len(csv_files)} CSV files:")
for f in csv_files:
    print(f"  - {f.name}")
# Out:
# Found 8 CSV files:
#   - baseline_outcome_dataset.csv
#   - BCVA.csv
#   - CST.csv
#   - Data.csv
#   - Demographics.csv
#   - DRSS.csv
#   - PrimeDR Biomarker Clinical Data Images.csv
#   - PrimeDR Clinical Data Images.csv

# %% [markdown]
# # Demographic CSV

# %%
# Read Demographics.csv
demo_df = pd.read_csv("Demographics.csv", header=[0,1])

print("Shape:", demo_df.shape)
print("\nColumn names:")
print(demo_df.columns.tolist())
print("\n" + "="*80)
print("First 5 rows:")
demo_df.head()
# Out:
# Shape: (40, 20)
#
# Column names:
# [('Patient Information', 'Patient \nID'), ('Unnamed: 1', 'Treatment Arm'), ('Unnamed: 2', 'Study\n Eye'), ('Unnamed: 3', 'Age'), ('Unnamed: 4', 'Gender'), ('Unnamed: 5', 'Ethnicity'), ('Unnamed: 6', 'Race'), ('Diabetes', 'Type of\n Diabetes'), ('Unnamed: 8', 'Number of Years with Diabetes'), ('Unnamed: 9', 'Baseline HbA1c'), ('Unnamed: 10', 'W24 HbA1c'), ('Unnamed: 11', 'W52 HbA1c'), ('Unnamed: 12', 'W76 HbA1c'), ('Unnamed: 13', 'W104 HbA1c'), ('Unnamed: 14', 'BMI (kg/m^2)'), ('Baseline', 'ETDRS BCVA'), ('Unnamed: 16', 'CST'), ('Unnamed: 17', 'Injection'), ('Unnamed: 18', 'DRSS'), ('Unnamed: 19', 'Leakage Index')]
#
# ================================================================================
# First 5 rows:
#   Patient Information    Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
#          Patient \nID Treatment Arm Study\n Eye        Age     Gender
# 0              01-001             2          OS         44          M
# 1              01-002             2          OD         56          F
# 2              01-013             2          OD         38          M
# 3              01-014             2          OS         55          M
# 4              01-023             2          OD         56          M
#
#   Unnamed: 5 Unnamed: 6           Diabetes                    Unnamed: 8  \
#    Ethnicity       Race Type of\n Diabetes Number of Years with Diabetes
# 0      N H/L      White                  2                            20
# 1      N H/L      White                  2                            25
# 2        H/L      White                  1                            13
# 3      N H/L      White                  2                            12
# 4        H/L      White                  2                            22
#
#       Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14  \
#   Baseline HbA1c   W24 HbA1c   W52 HbA1c   W76 HbA1c  W104 HbA1c BMI (kg/m^2)
# 0            7.1         8.7         8.4         9.1         8.4          NaN
# 1           11.3         9.1                     NaN         NaN    34.484657
# 2            8.0         9.5         9.6        11.7         9.8    25.997929
# 3           10.1         7.2         7.4         7.4         7.4    31.871377
# 4            7.1         6.7         5.9         6.9         NaN    35.669938
#
#     Baseline Unnamed: 16 Unnamed: 17 Unnamed: 18   Unnamed: 19
#   ETDRS BCVA         CST   Injection        DRSS Leakage Index
# 0         97         275         Yes          53          1.59
# 1         68         238         Yes          47          3.56
# 2         88         303         Yes          53          5.08
# 3         95         256         Yes          53          2.34
# 4         81         267         Yes          61          4.67

# %%
# Read with multi-level headers
demo_df = pd.read_csv("Demographics.csv", header=[0,1])

# Flatten the multi-level columns properly
# Strategy: Use level 1 (specific names), but if it's empty, use level 0
new_cols = []
for col in demo_df.columns:
    level0, level1 = col[0], col[1]
    
    # Clean whitespace
    level0 = level0.strip() if isinstance(level0, str) else str(level0)
    level1 = level1.strip() if isinstance(level1, str) else str(level1)
    
    # If level1 has actual content (not just whitespace), use it
    # Otherwise use level0
    if level1 and level1 != 'nan' and not level1.startswith('Unnamed'):
        new_cols.append(level1)
    elif level0 and not level0.startswith('Unnamed'):
        new_cols.append(level0)
    else:
        new_cols.append(f"{level0}_{level1}")

demo_df.columns = new_cols

print("Column names after flattening:")
print(demo_df.columns.tolist())
print("\nFirst 3 rows:")
demo_df.head(3)
# Out:
# Column names after flattening:
# ['Patient \nID', 'Treatment Arm', 'Study\n Eye', 'Age', 'Gender', 'Ethnicity', 'Race', 'Type of\n Diabetes', 'Number of Years with Diabetes', 'Baseline HbA1c', 'W24 HbA1c', 'W52 HbA1c', 'W76 HbA1c', 'W104 HbA1c', 'BMI (kg/m^2)', 'ETDRS BCVA', 'CST', 'Injection', 'DRSS', 'Leakage Index']
#
# First 3 rows:
#   Patient \nID  Treatment Arm Study\n Eye  Age Gender Ethnicity   Race  \
# 0       01-001              2          OS   44      M     N H/L  White
# 1       01-002              2          OD   56      F     N H/L  White
# 2       01-013              2          OD   38      M       H/L  White
#
#    Type of\n Diabetes  Number of Years with Diabetes  Baseline HbA1c  \
# 0                   2                             20             7.1
# 1                   2                             25            11.3
# 2                   1                             13             8.0
#
#    W24 HbA1c W52 HbA1c  W76 HbA1c  W104 HbA1c  BMI (kg/m^2)  ETDRS BCVA  CST  \
# 0        8.7       8.4        9.1         8.4           NaN          97  275
# 1        9.1                  NaN         NaN     34.484657          68  238
# 2        9.5       9.6       11.7         9.8     25.997929          88  303
#
#   Injection  DRSS  Leakage Index
# 0       Yes    53           1.59
# 1       Yes    47           3.56
# 2       Yes    53           5.08

# %%
# Check basic info
print("="*80)
print("DEMOGRAPHICS DATA SUMMARY")
print("="*80)

print(f"\nTotal patients: {len(demo_df)}")
print(f"\nUnique Patient IDs: {demo_df.iloc[:, 0].nunique()}")
print(f"\nFirst column values (Patient IDs):")
print(demo_df.iloc[:5, 0].values)

# check cats and dist.
print(f"\n--- Categorical Variables ---")
if 'Study_Eye' in demo_df.columns or 'Study\n Eye' in demo_df.columns:
    eye_col = 'Study_Eye' if 'Study_Eye' in demo_df.columns else demo_df.columns[2]
    print(f"\nStudy Eye distribution:")
    print(demo_df[eye_col].value_counts())

# Show numeric columns
print(f"\n--- Numeric Variables (summary) ---")
numeric_cols = demo_df.select_dtypes(include=[np.number]).columns
print(f"Numeric columns: {list(numeric_cols)}")
# Out:
# ================================================================================
# DEMOGRAPHICS DATA SUMMARY
# ================================================================================
#
# Total patients: 40
#
# Unique Patient IDs: 40
#
# First column values (Patient IDs):
# ['01-001' '01-002' '01-013' '01-014' '01-023']
#
# --- Categorical Variables ---
#
# Study Eye distribution:
# Study\n Eye
# OD    24
# OS    16
# Name: count, dtype: int64
#
# --- Numeric Variables (summary) ---
# Numeric columns: ['Treatment Arm', 'Age', 'Type of\n Diabetes', 'Number of Years with Diabetes', 'Baseline HbA1c', 'W24 HbA1c', 'W76 HbA1c', 'W104 HbA1c', 'BMI (kg/m^2)', 'ETDRS BCVA', 'CST', 'DRSS', 'Leakage Index']

# %%
# Basic statistics on numerics
print("\nBasic statistics:")
print(demo_df.describe())
# Out:
# Basic statistics:
#        Treatment Arm        Age  Type of\n Diabetes  \
# count       40.00000  40.000000           40.000000
# mean         1.50000  50.825000            1.875000
# std          0.50637  10.876669            0.334932
# min          1.00000  25.000000            1.000000
# 25%          1.00000  45.000000            2.000000
# 50%          1.50000  51.500000            2.000000
# 75%          2.00000  56.500000            2.000000
# max          2.00000  72.000000            2.000000
#
#        Number of Years with Diabetes  Baseline HbA1c  W24 HbA1c  W76 HbA1c  \
# count                      40.000000         40.0000  30.000000  20.000000
# mean                       15.825000          9.1150   8.503333   9.215000
# std                         8.421241          2.2147   1.788562   2.324305
# min                         0.000000          5.1000   4.600000   6.500000
# 25%                        11.000000          7.5500   7.400000   7.325000
# 50%                        15.000000          8.4500   8.250000   8.300000
# 75%                        21.250000         10.5750   9.025000  11.225000
# max                        33.000000         14.7000  13.700000  13.500000
#
#        W104 HbA1c  BMI (kg/m^2)  ETDRS BCVA         CST       DRSS  \
# count   21.000000     39.000000    40.00000   40.000000  40.000000
# mean     8.795238     32.749038    83.32500  270.300000  59.500000
# std      1.899072      8.284723     7.94012   24.418572   7.656068
# min      6.800000     18.194657    59.00000  220.000000  47.000000
# 25%      7.400000     28.132772    79.00000  256.000000  53.000000
# 50%      8.100000     32.820737    84.00000  272.000000  57.000000
# 75%      9.800000     35.307023    89.00000  284.750000  65.000000
# max     13.900000     65.541832    97.00000  312.000000  71.000000
#
#        Leakage Index
# count      40.000000
# mean        2.983750
# std         1.960137
# min         0.310000
# 25%         1.432500
# 50%         2.580000
# 75%         4.712500
# max         7.250000

# %%
print(f"\n--- Missing Data ---")
print(demo_df.isnull().sum())
# Out:
# --- Missing Data ---
# Patient \nID                      0
# Treatment Arm                     0
# Study\n Eye                       0
# Age                               0
# Gender                            0
# Ethnicity                         0
# Race                              0
# Type of\n Diabetes                0
# Number of Years with Diabetes     0
# Baseline HbA1c                    0
# W24 HbA1c                        10
# W52 HbA1c                        11
# W76 HbA1c                        20
# W104 HbA1c                       19
# BMI (kg/m^2)                      1
# ETDRS BCVA                        0
# CST                               0
# Injection                         0
# DRSS                              0
# Leakage Index                     0
# dtype: int64

# %% [markdown]
# Key findings:
#
# ✅ 40 eyes (24 OD, 16 OS) - this matches your thesis document
# ✅ Age range: 25-72 years (mean ~51)
#     years with Diabetes: 0-33 yrs
#     baseline Hba1c: 5.1 ~ 14.7
# ✅ Baseline BCVA: 83.3 ± 7.9 letters
# ✅ Baseline CST: 270 ± 24 μm
# ⚠️ Some missing HbA1c at follow-up visits (but baseline is complete)

# %% [markdown]
# # PrimeDR Clinical Data Images.csv

# %%
# Load PrimeDR Clinical Data Images.csv
clinical_df = pd.read_csv("PrimeDR Clinical Data Images.csv")

print("="*80)
print("CLINICAL DATA IMAGES (32K+ images with labels)")
print("="*80)

print(f"\nShape: {clinical_df.shape}")
print(f"\nColumns: {clinical_df.columns.tolist()}")
print(f"\nFirst 5 rows:")
print(clinical_df.head())

print(f"\n--- Data Summary ---")
print(f"Total image records: {len(clinical_df)}")
print(f"Unique patients: {clinical_df['Patient_ID'].nunique()}")
print(f"Unique eyes: {clinical_df['Eye_ID'].nunique()}")

print(f"\n--- File Path Examples (first 3) ---")
for path in clinical_df['File_Path'].head(3):
    print(f"  {path}")
# Out:
# ================================================================================
# CLINICAL DATA IMAGES (32K+ images with labels)
# ================================================================================
#
# Shape: (32337, 5)
#
# Columns: ['File_Path', 'BCVA', 'CST', 'Eye_ID', 'Patient_ID']
#
# First 5 rows:
#                          File_Path  BCVA    CST  Eye_ID  Patient_ID
# 0  /Prime_FULL/01-001/W0/OS/27.png  97.0  275.0      58          58
# 1   /Prime_FULL/01-001/W0/OS/0.png  97.0  275.0      58          58
# 2   /Prime_FULL/01-001/W0/OS/1.png  97.0  275.0      58          58
# 3  /Prime_FULL/01-001/W0/OS/10.png  97.0  275.0      58          58
# 4  /Prime_FULL/01-001/W0/OS/11.png  97.0  275.0      58          58
#
# --- Data Summary ---
# Total image records: 32337
# Unique patients: 40
# Unique eyes: 40
#
# --- File Path Examples (first 3) ---
#   /Prime_FULL/01-001/W0/OS/27.png
#   /Prime_FULL/01-001/W0/OS/0.png
#   /Prime_FULL/01-001/W0/OS/1.png

# %%
# Out:
# ================================================================================
# PRIME DATASET PREPROCESSING - PHASE 1: INSPECTION
# ================================================================================
#
#
# ### STEP 1: INSPECTING CSV STRUCTURES ###
#
#
# ================================================================================
# INSPECTING: Demographics
# ================================================================================
#
# Shape: 5 rows × 20 columns
#
# Column names:
# ['Patient Information', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Diabetes', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Baseline', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19']
#
# --- First 3 rows (showing first 10 columns) ---
#   Patient Information     Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0        Patient \nID  Treatment Arm  Study\n Eye        Age     Gender
# 1              01-001              2           OS         44          M
# 2              01-002              2           OD         56          F
#
#   Unnamed: 5 Unnamed: 6            Diabetes                     Unnamed: 8  \
# 0  Ethnicity       Race  Type of\n Diabetes  Number of Years with Diabetes
# 1      N H/L      White                   2                             20
# 2      N H/L      White                   2                             25
#
#        Unnamed: 9
# 0  Baseline HbA1c
# 1             7.1
# 2            11.3
#
# ================================================================================
# INSPECTING: BCVA
# ================================================================================
#
# Shape: 5 rows × 44 columns
#
# Column names:
# ['Patient Information', 'Unnamed: 1', 'Unnamed: 2', 'Screen', 'Week 4', 'Unnamed: 5', 'Week 8', 'Unnamed: 7', 'Week 12', 'Unnamed: 9', 'Week 16', 'Unnamed: 11', 'Week 20', 'Unnamed: 13', 'Week 24', 'Unnamed: 15', 'Week 28', 'Unnamed: 17', 'Week 32', 'Unnamed: 19', 'Week 36', 'Unnamed: 21', 'Week 40', 'Unnamed: 23', 'Week 44', 'Unnamed: 25', 'Week 48', 'Unnamed: 27', 'Week 52', 'Unnamed: 29', 'Week 60', 'Unnamed: 31', 'Week 68', 'Unnamed: 33', 'Week 76', 'Unnamed: 35', 'Week 84', 'Unnamed: 37', 'Week 92', 'Unnamed: 39', 'Week 100', 'Unnamed: 41', 'Week 104', 'Unnamed: 43']
#
# --- First 3 rows (showing first 10 columns) ---
#   Patient Information Unnamed: 1 Unnamed: 2 Screen Week 4 Unnamed: 5 Week 8  \
# 0          Patient ID        Eye        Arm   BCVA   BCVA     Change   BCVA
# 1              01-001         OS          2     97     98          1     97
# 2              01-002         OD          2     68     72          4     68
#
#   Unnamed: 7 Week 12 Unnamed: 9
# 0     Change    BCVA     Change
# 1          0      98          1
# 2          0      67         -1
#
# ================================================================================
# INSPECTING: CST
# ================================================================================
#
# Shape: 5 rows × 44 columns
#
# Column names:
# ['Patient Information', 'Unnamed: 1', 'Unnamed: 2', 'Screen', 'Week 4', 'Unnamed: 5', 'Week 8', 'Unnamed: 7', 'Week 12', 'Unnamed: 9', 'Week 16', 'Unnamed: 11', 'Week 20', 'Unnamed: 13', 'Week 24', 'Unnamed: 15', 'Week 28', 'Unnamed: 17', 'Week 32', 'Unnamed: 19', 'Week 36', 'Unnamed: 21', 'Week 40', 'Unnamed: 23', 'Week 44', 'Unnamed: 25', 'Week 48', 'Unnamed: 27', 'Week 52', 'Unnamed: 29', 'Week 60', 'Unnamed: 31', 'Week 68', 'Unnamed: 33', 'Week 76', 'Unnamed: 35', 'Week 84', 'Unnamed: 37', 'Week 92', 'Unnamed: 39', 'Week 100', 'Unnamed: 41', 'Week 104', 'Unnamed: 43']
#
# --- First 3 rows (showing first 10 columns) ---
#   Patient Information Unnamed: 1 Unnamed: 2 Screen Week 4 Unnamed: 5 Week 8  \
# 0          Patient ID        Eye        Arm    CST    CST     Change    CST
# 1              01-001         OS          2    275    268         -7    268
# 2              01-002         OD          2    238    233         -5    222
#
#   Unnamed: 7 Week 12 Unnamed: 9
# 0     Change     CST     Change
# 1         -7     265        -10
# 2        -16     222        -16
#
# ================================================================================
# INSPECTING: DRSS
# ================================================================================
#
# Shape: 5 rows × 67 columns
#
# Column names:
# ['Patient Information', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Screen', 'Unnamed: 6', 'Week 4', 'Unnamed: 8', 'Unnamed: 9', 'Week 8', 'Unnamed: 11', 'Unnamed: 12', 'Week 12', 'Unnamed: 14', 'Unnamed: 15', 'Week 16', 'Unnamed: 17', 'Unnamed: 18', 'Week 20', 'Unnamed: 20', 'Unnamed: 21', 'Week 24', 'Unnamed: 23', 'Unnamed: 24', 'Week 28', 'Unnamed: 26', 'Unnamed: 27', 'Week 32', 'Unnamed: 29', 'Unnamed: 30', 'Week 36', 'Unnamed: 32', 'Unnamed: 33', 'Week 40', 'Unnamed: 35', 'Unnamed: 36', 'Week 44', 'Unnamed: 38', 'Unnamed: 39', 'Week 48', 'Unnamed: 41', 'Unnamed: 42', 'Week 52', 'Unnamed: 44', 'Unnamed: 45', 'Week 60', 'Unnamed: 47', 'Unnamed: 48', 'Week 68', 'Unnamed: 50', 'Unnamed: 51', 'Week 76', 'Unnamed: 53', 'Unnamed: 54', 'Week 84', 'Unnamed: 56', 'Unnamed: 57', 'Week 92', 'Unnamed: 59', 'Unnamed: 60', 'Week 100', 'Unnamed: 62', 'Unnamed: 63', 'Week 104', 'Unnamed: 65', 'Unnamed: 66']
#
# --- First 3 rows (showing first 10 columns) ---
#   Patient Information  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          Patient ID         NaN         NaN        Eye        Arm
# 1              01-001         NaN         NaN         OS          2
# 2              01-002         NaN         NaN         OD          2
#
#        Screen     Unnamed: 6      Week 4 Unnamed: 8     Unnamed: 9
# 0  DRSS Level  Leakage Index  DRSS Level     Change  Leakage Index
# 1          53           1.59          53          0           0.28
# 2          47           3.56          47          0           0.23
#
#
# ### STEP 2: LOADING CLEAN FILES ###
#
#
# ================================================================================
# LOADING: PrimeDR Clinical Data Images (CLEAN FORMAT)
# ================================================================================
# ✓ Loaded 32337 image records
#
# Columns: ['File_Path', 'BCVA', 'CST', 'Eye_ID', 'Patient_ID']
#
# First 3 rows:
#                          File_Path  BCVA    CST  Eye_ID  Patient_ID
# 0  /Prime_FULL/01-001/W0/OS/27.png  97.0  275.0      58          58
# 1   /Prime_FULL/01-001/W0/OS/0.png  97.0  275.0      58          58
# 2   /Prime_FULL/01-001/W0/OS/1.png  97.0  275.0      58          58
#
# Data summary:
#   Unique patients: 40
#   Unique eyes: 40
#   Weeks available: [np.int64(0), np.int64(4), np.int64(8), np.int64(12), np.int64(16), np.int64(20), np.int64(24), np.int64(28), np.int64(32), np.int64(36), np.int64(40), np.int64(44), np.int64(48), np.int64(52), np.int64(60), np.int64(68), np.int64(76), np.int64(84), np.int64(92), np.int64(100), np.int64(104)]
#   Total images: 32337
#
# ================================================================================
# LOADING: PrimeDR Biomarker Data (CLEAN FORMAT)
# ================================================================================
# ✓ Loaded 3920 biomarker records
#
# Columns: ['Path (Trial/Arm/Folder/Visit/Eye/Image Name)', 'Scan (n/49)', 'Atrophy / thinning of retinal layers', 'Disruption of EZ', 'DRIL', 'IR hemorrhages', 'IR HRF', 'Partially attached vitreous face', 'Fully attached vitreous face', 'Preretinal tissue/hemorrhage', 'Vitreous debris', 'VMT', 'DRT/ME', 'Fluid (IRF)', 'Fluid (SRF)', 'Disruption of RPE', 'PED (serous)', 'SHRM', 'Eye_ID', 'BCVA', 'CST', 'Patient_ID']
#
# Biomarker columns: 16
#
# Data summary:
#   Unique patients: 40
#   Unique eyes: 40
#   OCT scans: 3920
#   Scans per eye (typical): 49
#
#
# ### STEP 3: CREATING BASELINE-OUTCOME DATASET ###
#
#
# ================================================================================
# CREATING BASELINE-OUTCOME PAIRS
# ================================================================================
# Baseline (W0): 1960 records
# Outcome (W104): 1127 records
#
# ✓ Created 55223 baseline-outcome pairs
#
# --------------------------------------------------------------------------------
# SUMMARY STATISTICS
# --------------------------------------------------------------------------------
#
# Baseline BCVA: 83.9 ± 7.3
# Outcome BCVA: 84.1 ± 7.8
# BCVA improvement: 0.2 ± 6.9 letters
#
# Baseline CST: 272 ± 27 μm
# Outcome CST: 263 ± 26 μm
#
# Responder Distribution:
#   Responders (≥10 letters): 4802 (8.7%)
#   Non-responders (<10 letters): 50421 (91.3%)
#
# ⚠ WARNING: Class imbalance detected! May need special handling.
#
# ✓ Saved baseline-outcome dataset to: baseline_outcome_dataset.csv
#
#
# ### STEP 4: PARSING COMPLEX CSVs (OPTIONAL) ###
#
# Run the following if you need additional data not in clean files:
#   bcva_long = parse_wide_format_csv('BCVA.csv', 'BCVA')
#   cst_long = parse_wide_format_csv('CST.csv', 'CST')
#   drss_long = parse_wide_format_csv('DRSS.csv', 'DRSS')
#
# ================================================================================
# INSPECTION COMPLETE!
# ================================================================================
#
# Next steps:
# 1. Review the baseline_outcome_dataset.csv
# 2. Check if you need demographics or DRSS data
# 3. Proceed to aggregate biomarkers for baseline eyes
# 4. Create train/val/test splits (patient-level!)
